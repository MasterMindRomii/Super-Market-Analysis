# %% [markdown]
# # Import Neccessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing Csv File

# %%
df=pd.read_csv(r'C:\Users\Dell\Desktop\75 Day\EDA-DAY7\supermarket_sales - Sheet1.csv', encoding = 'unicode_escape')

# %% [markdown]
# # Explore Data Information

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# 25%               4.761905e+00      5.924875     5.50000
# 50%               4.761905e+00     12.088000     7.00000
# 75%               4.761905e+00     22.445250     8.50000
# max               4.761905e+00     49.650000    10.00000

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# 1  10:29         Cash   76.40                 4.761905        3.8200     9.6
# 2  13:23  Credit card  324.31                 4.761905       16.2155     7.4
# 3  20:33      Ewallet  465.76                 4.761905       23.2880     8.4
# 4  10:37      Ewallet  604.17                 4.761905       30.2085     5.3

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# ## Acoording to the information there is no null values

# %% [markdown]
# # Check the data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
#  14  gross margin percentage  1000 non-null   float64
#  15  gross income             1000 non-null   float64
#  16  Rating                   1000 non-null   float64
# dtypes: float64(7), int64(1), object(9)
# memory usage: 132.9+ KB

# %% [markdown]
# ## Change date to pandas date datatype

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year #Extracting Year from Date
df['Month'] = df['Date'].dt.month #Extracting Month from Date
df['Day'] = df['Date'].dt.day #Extracting Day from Date

# %% [markdown]
# ## Changing columns to respective datatypes

# %%
df[['Payment','Branch','City','Customer type','Gender','Product line']]=df[['Payment','Branch','City','Customer type','Gender','Product line']].astype('category')

# %% [markdown]
# ## Dropping Invoice ID Column

# %%
df.drop('Invoice ID',axis='columns',inplace=True)

# %% [markdown]
# # After Manipulation of Data Types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   category
#  1   City                     1000 non-null   category
#  2   Customer type            1000 non-null   category
#  3   Gender                   1000 non-null   category
#  4   Product line             1000 non-null   category
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   datetime64[ns]
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   category
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
#  14  gross income             1000 non-null   float64
#  15  Rating                   1000 non-null   float64
#  16  Year                     1000 non-null   int64
#  17  Month                    1000 non-null   int64
#  18  Day                      1000 non-null   int64
# dtypes: category(6), datetime64[ns](1), float64(7), int64(4), object(1)
# memory usage: 108.4+ KB

# %% [markdown]
# # Unique Values of All Categorical Columns

# %%
df.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross margin percentage', 'gross income', 'Rating', 'Year',
#        'Month', 'Day'],
#       dtype='object')

# %%
df['Branch'].unique()
# Out:
# ['A', 'C', 'B']
# Categories (3, object): ['A', 'B', 'C']

# %%
df['City'].unique()
# Out:
# ['Yangon', 'Naypyitaw', 'Mandalay']
# Categories (3, object): ['Mandalay', 'Naypyitaw', 'Yangon']

# %%
df['Customer type'].unique()
# Out:
# ['Member', 'Normal']
# Categories (2, object): ['Member', 'Normal']

# %%
df['Gender'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Female', 'Male']

# %%
df['Product line'].unique()
# Out:
# ['Health and beauty', 'Electronic accessories', 'Home and lifestyle', 'Sports and travel', 'Food and beverages', 'Fashion accessories']
# Categories (6, object): ['Electronic accessories', 'Fashion accessories', 'Food and beverages', 'Health and beauty', 'Home and lifestyle', 'Sports and travel']

# %%
df['Quantity'].unique()
# Out:
# array([ 7,  5,  8,  6, 10,  2,  3,  4,  1,  9], dtype=int64)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Per Unit Price of Each Product Lines

# %%
sns.set_style('darkgrid')
ax = sns.lineplot(x=df['Product line'],y=df['Unit price'],data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.xlabel('Product Line')
plt.title('Per Unit Price of Each Product Lines')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3900\608085178.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ## Count of Different Types of Customers from Different Citiess

# %%
sns.set_style('darkgrid')
ax=sns.countplot(x=df['Customer type'],data=df,hue=df['City'])
plt.xlabel=('Customer type')
plt.title('Count of Different Types of Customers from Different Cities')
plt.legend(title='City',loc='upper right')
plt.show()

# %% [markdown]
# ## Count of Different Types of Products in Super Market

# %%
sns.set_style('darkgrid')
ax = sns.countplot(x=df['Product line'],data=df,order=df['Product line'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.xlabel('Product Line')
plt.title('Count of Different Types of Products in Super Market')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2 ax = sns.countplot(x=df['Product line'],data=df,order=df['Product line'].value_counts().index)
#       3 ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ----> 4 plt.xlabel('Product Line')
#       5 plt.title('Count of Different Types of Products in Super Market')
#       6 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Count of Different Gender Visitors at Different Branches

# %%
sns.set_style('darkgrid')
ax=sns.countplot(x=df['Gender'],data=df,hue='Branch')
plt.xlabel('Branch')
plt.title('Count of Different Gender Visitors at Different Branches')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 sns.set_style('darkgrid')
#       2 ax=sns.countplot(x=df['Gender'],data=df,hue='Branch')
# ----> 3 plt.xlabel('Branch')
#       4 plt.title('Count of Different Gender Visitors at Different Branches')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Count of Different Types of Payment Methods used by Different Genders

# %%
sns.set_style('darkgrid')
ax=sns.countplot(x=df['Payment'],data=df,hue='Gender')
plt.xlabel='Gender'
plt.title('Count of Different Types of Payment Methods used by Different Gender')
plt.show()

# %% [markdown]
# ## Count of Different Gender Visitors from Different Cities

# %%
sns.set_style('darkgrid')
ax=sns.countplot(x=df['City'],data=df,hue='Gender')
plt.xlabel('City')
plt.title('Count of Different Gender Visitors from Different Cities')
plt.legend(title='Gender',loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 sns.set_style('darkgrid')
#       2 ax=sns.countplot(x=df['City'],data=df,hue='Gender')
# ----> 3 plt.xlabel('City')
#       4 plt.title('Count of Different Gender Visitors from Different Cities')
#       5 plt.legend(title='Gender',loc='upper right')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# ## Different Payment Methods Used by Different Cities

# %%
sns.set_style('darkgrid')
ax=sns.countplot(x=df['City'],data=df,hue='Payment')
plt.xlabel('Payment')
plt.title('Different Payment Methods Used by Different Cities')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 sns.set_style('darkgrid')
#       2 ax=sns.countplot(x=df['City'],data=df,hue='Payment')
# ----> 3 plt.xlabel('Payment')
#       4 plt.title('Different Payment Methods Used by Different Cities')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Refrence

# %% [markdown]
# ## Total Amount Spend on Different Product Lines by different gender

# %%
sns.set_style('darkgrid')
ax = sns.lineplot(x=df['Product line'],y=df['Total'],data=df,hue=df['Gender'],err_style=None)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.title('Total Amount Spend on Different Product Lines by Different Genders')
plt.legend(title='Gender',loc='upper right')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3900\3336502826.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)

# %% [markdown]
# ## Rating of Different Product Lines by Different Genders

# %%
sns.set_style('darkgrid')
ax = sns.lineplot(x=df['Product line'],y=df['Rating'],data=df,hue=df['Gender'],err_style=None)
ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
plt.xlabel('Product Line')
plt.title('Rating of Different Product Lines by Different Genders')
plt.legend(title='Gender',loc='upper right')
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3900\2606733758.py:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 4
#       2 ax = sns.lineplot(x=df['Product line'],y=df['Rating'],data=df,hue=df['Gender'],err_style=None)
#       3 ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
# ----> 4 plt.xlabel('Product Line')
#       5 plt.title('Rating of Different Product Lines by Different Genders')
#       6 plt.legend(title='Gender',loc='upper right')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # Th
